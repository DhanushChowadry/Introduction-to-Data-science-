# %% [markdown]
# # Step-1:Install Packages

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# # Step-2: Import packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Step-3:Load Dataset

# %%
data=pd.read_csv('/content/ecommerce_customer_data_custom_ratios(project-6).zip')

# %% [markdown]
# # Step-4:Cleaning

# %%
data.head(10)
# Out:
#    Customer ID        Purchase Date Product Category  Product Price  Quantity  \
# 0        46251  2020-09-08 09:38:32      Electronics             12         3
# 1        46251  2022-03-05 12:56:35             Home            468         4
# 2        46251  2022-05-23 18:18:01             Home            288         2
# 3        46251  2020-11-12 13:13:29         Clothing            196         1
# 4        13593  2020-11-27 17:55:11             Home            449         1
# 5        13593  2023-03-07 14:17:42             Home            250         4
# 6        13593  2023-04-15 03:02:33      Electronics             73         1
# 7        13593  2021-03-27 21:23:28            Books            337         2
# 8        13593  2020-05-05 20:14:00         Clothing            182         2
# 9        28805  2023-09-13 04:24:00      Electronics            394         2
#
#    Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
data.tail(10)
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 249990         5977  2021-08-05 21:36:18            Books             44
# 249991        17165  2020-02-25 13:38:16         Clothing            230
# 249992        45397  2022-02-18 04:18:18            Books             95
# 249993        35965  2022-10-13 19:48:58             Home             83
# 249994        45410  2021-05-30 15:37:15             Home            311
# 249995        33308  2023-08-10 13:39:06         Clothing            279
# 249996        48835  2021-11-23 01:30:42             Home             27
# 249997        21019  2020-07-02 14:04:48             Home             17
# 249998        49234  2020-12-30 02:02:40            Books            398
# 249999        16971  2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# 249990         1                   1064    Credit Card            34      NaN
# ...

# %%
data.shape
# Out:
# (250000, 13)

# %%
data.describe()
# Out:
#         Customer ID  Product Price       Quantity  Total Purchase Amount  \
# count  250000.00000  250000.000000  250000.000000          250000.000000
# mean    25004.03624     254.659512       2.998896            2725.370732
# std     14428.27959     141.568577       1.414694            1442.933565
# min         1.00000      10.000000       1.000000             100.000000
# 25%     12497.75000     132.000000       2.000000            1477.000000
# 50%     25018.00000     255.000000       3.000000            2724.000000
# 75%     37506.00000     377.000000       4.000000            3974.000000
# max     50000.00000     500.000000       5.000000            5350.000000
#
#         Customer Age        Returns            Age          Churn
# count  250000.000000  202404.000000  250000.000000  250000.000000
# mean       43.940528       0.497861      43.940528       0.199496
# std        15.350246       0.499997      15.350246       0.399622
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  object
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   Payment Method         250000 non-null  object
#  7   Customer Age           250000 non-null  int64
#  8   Returns                202404 non-null  float64
#  9   Customer Name          250000 non-null  object
#  10  Age                    250000 non-null  int64
#  11  Gender                 250000 non-null  object
#  12  Churn                  250000 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 24.8+ MB

# %% [markdown]
# # Step-5:Finding Null-Values

# %%
data.isnull().sum()
# Out:
# Customer ID                  0
# Purchase Date                0
# Product Category             0
# Product Price                0
# Quantity                     0
# Total Purchase Amount        0
# Payment Method               0
# Customer Age                 0
# Returns                  47596
# Customer Name                0
# Age                          0
# Gender                       0
# Churn                        0
# dtype: int64

# %% [markdown]
# # Step-6:Filling Null Values

# %%
data['Returns'].fillna(data['Returns'].mode()[0],inplace=True)
# Out:
# <ipython-input-10-995c17170c6c>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Returns'].fillna(data['Returns'].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# Customer ID              0
# Purchase Date            0
# Product Category         0
# Product Price            0
# Quantity                 0
# Total Purchase Amount    0
# Payment Method           0
# Customer Age             0
# Returns                  0
# Customer Name            0
# Age                      0
# Gender                   0
# Churn                    0
# dtype: int64

# %% [markdown]
# # Step-7:Visualization Techniques

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Basic Plot

# %%
data.head()
# Out:
#    Customer ID        Purchase Date Product Category  Product Price  Quantity  \
# 0        46251  2020-09-08 09:38:32      Electronics             12         3
# 1        46251  2022-03-05 12:56:35             Home            468         4
# 2        46251  2022-05-23 18:18:01             Home            288         2
# 3        46251  2020-11-12 13:13:29         Clothing            196         1
# 4        13593  2020-11-27 17:55:11             Home            449         1
#
#    Total Purchase Amount Payment Method  Customer Age  Returns  \
# 0                    740    Credit Card            37      0.0
# 1                   2739         PayPal            37      0.0
# 2                   3196         PayPal            37      0.0
# 3                   3509         PayPal            37      0.0
# 4                   3452    Credit Card            49      0.0
#
#          Customer Name  Age  Gender  Churn
# 0  Christine Hernandez   37    Male      0
# ...

# %%
#lineplot
sns.lineplot(x='Age',y='Payment Method',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Payment Method'>

# %%
#barplot
sns.barplot(x='Age',y='Payment Method',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Payment Method'>

# %%
#scatterplot
sns.scatterplot(x='Age',y='Payment Method',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Payment Method'>

# %%
#hue
sns.barplot(x='Age',y='Payment Method',hue='Gender',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Payment Method'>

# %% [markdown]
# # UNIVARIATE:

# %%
#histogram
sns.histplot(data['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#boxplot
sns.boxplot(data['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
#violinplot
sns.violinplot(data['Age'])
# Out:
# <Axes: ylabel='Age'>

# %% [markdown]
# # Bivariate:

# %%
#scatterplot
sns.scatterplot(x='Age',y='Payment Method',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Payment Method'>

# %%
#boxplot
sns.boxplot(x='Age',y='Payment Method',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Payment Method'>

# %% [markdown]
# # Multivariate:

# %%
#pairplot
sns.pairplot(data)

# %%
#jointplot
sns.jointplot(x='Age',y='Payment Method',data=data)

# %% [markdown]
# # Questions

# %%
#Which product categories generate the highest revenue and which are the most popular based on quantity purchased?
sns.barplot(x='Product Category',y='Total Purchase Amount',data=data)
# Out:
# <Axes: xlabel='Product Category', ylabel='Total Purchase Amount'>

# %%
data.groupby('Product Category')['Quantity'].sum()
# Out:
# Product Category
# Books          223876
# Clothing       225322
# Electronics    150828
# Home           149698
# Name: Quantity, dtype: int64

# %%
#What are the most popular payment methods, and how do they relate to the total purchase amount or frequency of purchases?
sns.scatterplot(x='Payment Method',y='Total Purchase Amount',data=data)
# Out:
# <Axes: xlabel='Payment Method', ylabel='Total Purchase Amount'>
